# %% [markdown]
# ### 초간단 사용 - 네이버 검색 API
# - urllib: http 프로토콜에 따라서 서버의 요청/응답을 처리하기 위한 모듈
# - urllib.request: 클라이언트의 요청을 처리하는 모듈
# - urllib.parse: url 주소에 대한 분석

# %%
import os
import sys
import urllib.request

# %%
client_id='0NHdhlOYv4m4Hey1Ln4g'
client_secret='vhdtXt8MXv'

# %% [markdown]
# #### 블로그

# %%
encText=urllib.parse.quote('파이썬')
url='https://openapi.naver.com/v1/search/blog.json?query=' + encText # json 결과

# request 객체에 접속 정보 입력 (url, id, secret)
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-secret", client_secret)

# url 접속
response = urllib.request.urlopen(request)
rescode = response.getcode() # 접속에 대한 서버 응답
if(rescode == 200):
    response_body = response.read()
    print(response_body.decode('utf-8')) # 디코딩
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Mon, 02 Nov 2020 11:00:42 +0900",
# "total": 179634,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>파이썬</b> 학원 집중해야 할 포인트",
# "link": "https:\/\/blog.naver.com\/km_y?Redirect=Log&logNo=222122522937",
# "description": "1학년 필수 교양을 먼저 배우는 것이 낫겠다 싶어 <b>파이썬</b> 학원을 다니고자 결정을 내릴 수 있었던... 그렇게 <b>파이썬</b> 학원에 등록을 하고 배우기 시작했어요. 아, 제가 배우면서 가장 좋았던 점은 처음 상담을... ",
# "bloggername": "김과장 블로그",
# "bloggerlink": "https://blog.naver.com/km_y",
# "postdate": "20201021"
#
# },
# {
# "title": "<b>파이썬</b>(Phython)이 스타트업에게 인기있는 이유 7가지",
# "link": "http://blog.wishket.com/%ED%8C%8C%EC%9D%B4%EC%8D%ACpython%EC%9D%B4-%EC%8A%A4%ED%83%80%ED%8A%B8%EC%97%85%EC%97%90%EA%B2%8C-%EC%9D%B8%EA%B8%B0%EC%9E%88%EB%8A%94-%EC%9D%B4%EC%9C%A0-7%EA%B0%80%EC%A7%80/",
# "description": "<b>파이썬</b>(Python)이 스타트업에게 인기있는 이유 7가지 Facebook Twitter 안녕하세요. 위시켓입니다.... 그렇기 때문에 <b>파이썬</b>(Python)과 같은 강력하면서도 기반이 튼튼한 기술을 사용하는 것이 가장 좋습니다.... ",
# "bloggername": "그린 클라이언트 – Wishket",
# ...

# %% [markdown]
# #### 책

# %%
encText=urllib.parse.quote('파이썬')
url='https://openapi.naver.com/v1/search/book?query=' + encText # json 결과

# request 객체에 접속 정보 입력 (url, id, secret)
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-secret", client_secret)

# url 접속
response = urllib.request.urlopen(request)
rescode = response.getcode() # 접속에 대한 서버 응답
if(rescode == 200):
    response_body = response.read()
    print(response_body.decode('utf-8')) # 디코딩
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Mon, 02 Nov 2020 11:00:58 +0900",
# "total": 1144,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "이것이 취업을 위한 코딩 테스트다 with <b>파이썬</b> (취업과 이직을 결정하는 알고리즘 인터뷰 완벽 가이드, C/C++, 자바 코드 제공)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16439154",
# "image": "https://bookthumb-phinf.pstatic.net/cover/164/391/16439154.jpg?type=m1&udate=20200928",
# "author": "나동빈",
# "price": "34000",
# "discount": "30600",
# "publisher": "한빛미디어",
# "pubdate": "20200805",
# "isbn": "1162243074 9791162243077",
# "description": "8가지 핵심 알고리즘 이론을 쉽게 설명하고, 관련 실전 문제를 풀이했다. 출제 유형 분석, 이론 설명, 기출문제 풀이까지! 어떤 코딩 테스트도 이 책 한 권으로 대비할 수 있을 것이다. 코딩 테스트에서 주로 선택하는 <b>파이썬</b>을 기반으로 설명되어 있으며, <b>파이썬</b> 코드 외에도 C/C++, 자바 코드를 추가로 제공한다."
#
# },
# {
# "title": "<b>파이썬</b> 알고리즘 인터뷰 (95가지 알고리즘 문제 풀이로 완성하는 코딩 테스트)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16406247",
# "image": "https://bookthumb-phinf.pstatic.net/cover/164/062/16406247.jpg?type=m1&udate=20201028",
# ...

# %% [markdown]
# #### 영화

# %%
encText=urllib.parse.quote('파이썬')
url='https://openapi.naver.com/v1/search/movie?query=' + encText # json 결과

# request 객체에 접속 정보 입력 (url, id, secret)
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-secret", client_secret)

# url 접속
response = urllib.request.urlopen(request)
rescode = response.getcode() # 접속에 대한 서버 응답
if(rescode == 200):
    response_body = response.read()
    print(response_body.decode('utf-8')) # 디코딩
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Mon, 02 Nov 2020 11:04:43 +0900",
# "total": 1,
# "start": 1,
# "display": 1,
# "items": [
# {
# "title": "<b>파이썬</b> 앤 가드",
# "link": "https://movie.naver.com/movie/bi/mi/basic.nhn?code=152070",
# "image": "https://ssl.pstatic.net/imgmovie/mdi/mit110/1520/152070_P01_145336.jpg",
# "subtitle": "PYTHON AND GUARD",
# "pubDate": "2015",
# "director": "안톤 디아코프|",
# "actor": "",
# "userRating": "0.00"
#
# }
# ]
# }

# %% [markdown]
# #### 카페

# %%
encText=urllib.parse.quote('파이썬')
url='https://openapi.naver.com/v1/search/cafearticle.json?query=' + encText # json 결과

# request 객체에 접속 정보 입력 (url, id, secret)
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-secret", client_secret)

# url 접속
response = urllib.request.urlopen(request)
rescode = response.getcode() # 접속에 대한 서버 응답
if(rescode == 200):
    response_body = response.read()
    print(response_body.decode('utf-8')) # 디코딩
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Mon, 02 Nov 2020 11:09:18 +0900",
# "total": 91669,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>파이썬</b> 코딩 빠르게 할려면?",
# "link": "http://cafe.naver.com/fx8300/698502",
# "description": "지난번에 <b>파이썬</b> 코딩하는데 자기 놋북으로 10시간 걸린다고 거실 데탑으로 해 보더니 2시간 걸리더라구요. <b>파이썬</b> 코딩 좀 빠르게 할려면 오버 안한다는 조건으로 어떤걸로 업하면 체감이 될런지.. 현재 라이젠5... ",
# "cafename": "AMD 비쉐라 라이젠 컴퓨터 사용자 모임",
# "cafeurl": "https://cafe.naver.com/fx8300"
#
# },
# {
# "title": "<b>파이썬</b> 하실때 어떤 IDE 사용하세요?",
# "link": "http://cafe.naver.com/inmacbook/2315834",
# "description": "이야~~ 맥북 사서 이것저것 사다보니까 이제 개발 공부좀 하려고 하네요 그래서 c++ 공부좀 할까 했는데 <b>파이썬</b>이 쉽다고 하고 사용하기도 편하다고들 해서 <b>파이썬</b> 공부좀 하려고 하는데 다들 어떤 IDE 쓰시나요... ",
# "cafename": "맥 쓰는 사람들 [구 맥북을 쓰는 사람...",
# "cafeurl": "https://cafe.naver.com/inmacbook"
#
# },
# {
# "title": "[제20443차] 시간순삭 <b>파이썬</b> / 생능출판사 (8.29 - 9.1)",
# "link": "http://cafe.naver.com/booknbeanstalk/986308",
# ...

# %% [markdown]
# #### 쇼핑

# %%
encText=urllib.parse.quote('파이썬')
url='https://openapi.naver.com/v1/search/shop?query=' + encText # json 결과

# request 객체에 접속 정보 입력 (url, id, secret)
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-secret", client_secret)

# url 접속
response = urllib.request.urlopen(request)
rescode = response.getcode() # 접속에 대한 서버 응답
if(rescode == 200):
    response_body = response.read()
    print(response_body.decode('utf-8')) # 디코딩
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Mon, 02 Nov 2020 11:11:24 +0900",
# "total": 208719,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "[숑부티크] 32타입 A라인 프린트 나염 실키 롱스커트 / 실크 새틴 플라워 플로럴 꽃나염 블루 에메랄드 데이지 튤립 페인팅 뱀피 <b>파이톤</b> 호피 레오파드 도트",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82419205697",
# "image": "https://shopping-phinf.pstatic.net/main_8241920/82419205697.6.jpg",
# "lprice": "18500",
# "hprice": "0",
# "mallName": "숑숑150",
# "productId": "82419205697",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "패션의류",
# "category2": "여성의류",
# "category3": "스커트",
# "category4": ""
#
# },
# {
# "title": "와니 미니숄더백 <b>파이톤</b> 바게트백 스트랩2개",
# "link": "https://search.shopping.naver.com/gate.nhn?id=21067843729",
# "image": "https://shopping-phinf.pstatic.net/main_2106784/21067843729.20200305033312.jpg",
# "lprice": "16000",
# "hprice": "18700",
# "mallName": "네이버",
# "productId": "21067843729",
# "productType": "1",
# "brand": "",
# "maker": "",
# ...

# %% [markdown]
# #### 쇼핑 - 상품 검색

# %%
encText=urllib.parse.quote('몰스킨')
url='https://openapi.naver.com/v1/search/shop?query=' + encText # json 결과

# request 객체에 접속 정보 입력 (url, id, secret)
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-secret", client_secret)

# url 접속
response = urllib.request.urlopen(request)
rescode = response.getcode() # 접속에 대한 서버 응답
if(rescode == 200):
    response_body = response.read()
    print(response_body.decode('utf-8')) # 디코딩
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Mon, 02 Nov 2020 11:13:07 +0900",
# "total": 39256,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>몰스킨</b> 2021 다이어리 데일리 위클리 먼슬리 A5 고급 명품 감성 업무용 회사 기업 각인",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82635708485",
# "image": "https://shopping-phinf.pstatic.net/main_8263570/82635708485.jpg",
# "lprice": "24100",
# "hprice": "0",
# "mallName": "에코펜",
# "productId": "82635708485",
# "productType": "2",
# "brand": "몰스킨",
# "maker": "몰스킨",
# "category1": "생활/건강",
# "category2": "문구/사무용품",
# "category3": "다이어리/플래너",
# "category4": "다이어리"
#
# },
# {
# "title": "<b>몰스킨</b> <b>몰스킨</b> 2021 데일리 12M 다이어리 소프트커버 라지 사파이어블루",
# "link": "https://search.shopping.naver.com/gate.nhn?id=24014109279",
# "image": "https://shopping-phinf.pstatic.net/main_2401410/24014109279.20200903005345.jpg",
# "lprice": "24900",
# "hprice": "49640",
# "mallName": "네이버",
# "productId": "24014109279",
# "productType": "1",
# "brand": "몰스킨",
# "maker": "몰스킨",
# ...

# %% [markdown]
# ### 상품 검색 순서도
# - 1. gen_search_url(generate url)
#     - url 만들고
# - 2. get_result_onpage(Get data on one page)
#     - request, response
# - 3. get_field(Convert pandas data frame)
#     - 형변환 >> DF
# - 4. actMain(All Data gathering)
# - 5. toExcel(Export to Excel)

# %%
# 1. gen_search_url(generate url)

# %%
def gen_search_url(api_node, search_text, start_num, disp_num):
    base = "https://openapi.naver.com/v1/search"
    node = "/" + api_node + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text)
    param_start = "&start=" + str(start_num)
    param_disp = "&display=" + str(disp_num)
    return base + node + param_query + param_start + param_disp

# %%
gen_search_url('shop', 'TEST', 10, 3)
# Out:
# 'https://openapi.naver.com/v1/search/shop.json?query=TEST&start=10&display=3'

# %%
# 2. get_result_onpage(Get data on one page)

# %%
import json
import datetime

# %%
def get_result_onpage(url):
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-secret", client_secret)
    
    response = urllib.request.urlopen(request)
    
    print("[%s] Url Request Success" % datetime.datetime.now())
    return json.loads(response.read().decode('utf-8'))

# %%
url = gen_search_url('shop', '몰스킨', 1, 5)
one_result = get_result_onpage(url)
# Out:
# [2020-11-02 11:40:49.960476] Url Request Success

# %%
one_result

# %%
# 3. get_field(Convert pandas data frame)

# %%
one_result['items'][0]['title']
# Out:
# '<b>몰스킨</b> 2021 다이어리 데일리 위클리 먼슬리 A5 고급 명품 감성 업무용 회사 기업 각인'

# %%
one_result['items'][0]['lprice']
# Out:
# '24100'

# %%
one_result['items'][0]['mallName']
# Out:
# '에코펜'

# %%
# title의 <b> </b>를 제거 하기 위해
def delete_tag(input_str):
    input_str = input_str.replace("<b>", "")
    input_str = input_str.replace("</b>", "")
    return input_str

# %%
import pandas as pd
def get_fields(json_data):
    title = [delete_tag(each['title']) for each in json_data['items']]
    link = [each['link'] for each in json_data['items']]
    lprice = [each['lprice'] for each in json_data['items']]
    hprice = [each['hprice'] for each in json_data['items']]
    mall_name = [each['mallName'] for each in json_data['items']]
    
    result_pd = pd.DataFrame({
        'title': title, 'lprice': lprice, 'hprice': hprice, 'link': link,
        'mall': mall_name},
        columns = ['title', 'lprice', 'hprice', 'link', "mall"])
    return result_pd

# %%
pd_result = get_fields(one_result)

# %%
pd_result
# Out:
#                                                title lprice hprice  \
# 0  몰스킨 2021 다이어리 데일리 위클리 먼슬리 A5 고급 명품 감성 업무용 회사 기...  24100      0
# 1          몰스킨 몰스킨 2021 데일리 12M 다이어리 소프트커버 라지 사파이어블루  24900  49640
# 2                                 몰스킨 클래식노트 플레인 하드 L  17970  59400
# 3                              몰스킨 클래식노트 플레인 W.그린 하드  18390  36900
# 4                                      몰스킨 클래식 룰드 줄지  19060  36900
#
#                                                 link mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...  에코펜
# 1  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 3  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...  네이버

# %%
# 4. actMain(All Data gathering)

# %%
for n in range(1, 1000, 100):
    print(n)
# Out:
# 1
# 101
# 201
# 301
# 401
# 501
# 601
# 701
# 801
# 901

# %%
result_mol=[]
for n in range(1, 1000, 100):
    url = gen_search_url('shop', '몰스킨', n, 100)
    json_result = get_result_onpage(url)
    pd_result = get_fields(json_result)
    
    result_mol.append(pd_result)
    
result_mol = pd.concat(result_mol)
# Out:
# [2020-11-02 13:09:18.656798] Url Request Success
# [2020-11-02 13:09:18.958144] Url Request Success
# [2020-11-02 13:09:19.130012] Url Request Success
# [2020-11-02 13:09:19.338495] Url Request Success
# [2020-11-02 13:09:19.510314] Url Request Success
# [2020-11-02 13:09:19.810029] Url Request Success
# [2020-11-02 13:09:20.060983] Url Request Success
# [2020-11-02 13:09:20.310994] Url Request Success
# [2020-11-02 13:09:20.467410] Url Request Success
# [2020-11-02 13:09:20.670202] Url Request Success

# %%
result_mol
# Out:
#                                                 title  lprice  hprice  \
# 0   몰스킨 2021 다이어리 데일리 위클리 먼슬리 A5 고급 명품 감성 업무용 회사 기...   24100       0
# 1           몰스킨 몰스킨 2021 데일리 12M 다이어리 소프트커버 라지 사파이어블루   24900   49640
# 2                                  몰스킨 클래식노트 플레인 하드 L   17970   59400
# 3                               몰스킨 클래식노트 플레인 W.그린 하드   18390   36900
# 4                                       몰스킨 클래식 룰드 줄지   19060   36900
# ..                                                ...     ...     ...
# 95                               몰스킨 프로페셔널 노트 하드커버 라지   36300   47000
# 96                           몰스킨 아트컬렉션-스케치 앨범 K.브라운 L   15130   22000
# 97                       몰스킨 드래곤볼 하드커버 도트 라지 노트(색상선택)   39600       0
# 98    몰스킨 oleskine Lineage Backpack Leather 3200650-M  328020  601680
# 99                      한정판 몰스킨 노트 데님 하드커버 룰드 라지 프러시안   31730   36300
#
#                                                  link mall
# 0   https://search.shopping.naver.com/gate.nhn?id=...  에코펜
# ...

# %%
# index가 0 ~ 99 로만 되어 있기에 수정 필요
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   object
#  2   hprice  1000 non-null   object
#  3   link    1000 non-null   object
#  4   mall    1000 non-null   object
# dtypes: object(5)
# memory usage: 39.2+ KB

# %%
result_mol.reset_index(drop=True, inplace=True)
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   object
#  2   hprice  1000 non-null   object
#  3   link    1000 non-null   object
#  4   mall    1000 non-null   object
# dtypes: object(5)
# memory usage: 39.2+ KB

# %%
result_mol.head()
# Out:
#                                                title lprice hprice  \
# 0  몰스킨 2021 다이어리 데일리 위클리 먼슬리 A5 고급 명품 감성 업무용 회사 기...  24100      0
# 1          몰스킨 몰스킨 2021 데일리 12M 다이어리 소프트커버 라지 사파이어블루  24900  49640
# 2                                 몰스킨 클래식노트 플레인 하드 L  17970  59400
# 3                              몰스킨 클래식노트 플레인 W.그린 하드  18390  36900
# 4                                      몰스킨 클래식 룰드 줄지  19060  36900
#
#                                                 link mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...  에코펜
# 1  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 3  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...  네이버

# %%
# 가격은 float형으로
result_mol['lprice'] = result_mol['lprice'].astype('float')
result_mol['hprice'] = result_mol['hprice'].astype('float')
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   float64
#  2   hprice  1000 non-null   float64
#  3   link    1000 non-null   object
#  4   mall    1000 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 39.2+ KB

# %%
# 5. toExcel(Export to Excel)

# %%
writer = pd.ExcelWriter("./datas/06_molskin_diary_in_naver_shop.xlsx", 
                       engine='xlsxwriter')
result_mol.to_excel(writer, sheet_name = 'Sheet1')

workbook = writer.book
worksheet = writer.sheets['Sheet1']
worksheet.set_column('A:A', 4)
worksheet.set_column('B:B', 60)
worksheet.set_column('C:C', 10)
worksheet.set_column('D:D', 10)
worksheet.set_column('E:E', 50)
worksheet.set_column('F:F', 10)

worksheet.conditional_format('C2:C1001', {'type': '3_color_scale'})

writer.save()

# %% [markdown]
# ### 하나만더

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

f_path = "C://Windows/Fonts/malgun.ttf"
f_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=f_name)

# %%
# 몰스킨 노트 판매자 조회
plt.figure(figsize=(15,6))
sns.countplot('mall', data=result_mol, palette='RdYlGn',
             order=result_mol['mall'].value_counts().index)
plt.xticks(rotation=90)
plt.show()
